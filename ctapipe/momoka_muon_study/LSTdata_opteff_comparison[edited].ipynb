# %%
"comparing LSTCam data for different optical efficiency"
# Out:
# 'comparing LSTCam data for different optical efficiency'

# %%
#import ctapipe
from ctapipe.utils.datasets import get_dataset_path
from ctapipe.io import event_source, EventSeeker
from ctapipe.visualization import CameraDisplay
from ctapipe.image import tailcuts_clean
from ctapipe.image.muon import MuonRingFitter
from matplotlib import pyplot as plt
from astropy import units as u
import numpy as np

# %%
#files to read (100)
filename1 = "/Users/momokagoto/ctaTestFiles/opt_eff_100/muon_0deg_0deg_run171___cta-prod3-lst_desert-2150m-Paranal-lst.simtel.gz"
filename2 = "/Users/momokagoto/ctaTestFiles/opt_eff_60/muon_0deg_0deg_run471___cta-prod3-lst_desert-2150m-Paranal-lst.simtel.gz"

# %%
fit_values=[]
true_inclination_list=[]
true_radius_list=[]
true_centerx_list=[]
true_centery_list=[]
pixelcharge_all=[]
pixelnumber_all=[]
avgdist_all=[]


allcenterx_t=[]
allcentery_t=[]
allradius_t=[]
error_xvalues_t=[]
error_yvalues_t=[]
error_radius_t=[]
chisquares_t=[]
inclination_list_t=[]

allcenterx_ck=[]
allcentery_ck=[]
allradius_ck=[]
error_xvalues_ck=[]
error_yvalues_ck=[]
error_radius_ck=[]
chisquares_ck=[]
inclination_list_ck=[]

allcenterx_h = []
allcentery_h = []
allradius_h = []
error_xvalues_h = []
error_yvalues_h = []
error_radius_h = []
chisquares_h = []
inclination_list_h = []

# %%
source1 = event_source(filename1)
for event in source1:
    
    if event.count >100:
        break
        
    from ctapipe.calib import CameraCalibrator
    calib = CameraCalibrator()
    calib(event)

    tel_id = sorted(event.r1.tels_with_data)[0]
    sub = event.inst.subarray
    camera = sub.tel[tel_id].camera
    optics = sub.tel[tel_id].optics
    image = event.dl1.tel[tel_id].image

    for telid in event.dl0.tels_with_data:

        # Get geometry
        teldes = event.inst.subarray.tel[telid]
        focal_length= teldes.optics.equivalent_focal_length
        geom = teldes.camera

        mask = tailcuts_clean(geom, image, 5, 7)
        image[~mask] = 0
        x, y = np.array(geom.pix_x), np.array(geom.pix_y)
        
        squared_distanced = (x[0] - x[1:])**2 + (y[0] - y[1:])**2
        angle_pix_width = np.sqrt(squared_distanced.min())
        
        for method in MuonRingFitter.fit_method.values:

            muonfit = MuonRingFitter(fit_method=method)
            fit_result = muonfit(geom.pix_x, geom.pix_y, image, mask)
            
            #plt.figure(figsize=(5,5))
            disp = CameraDisplay(geom, image)
            
            xc_fit = fit_result.ring_center_x.to_value(u.m) 
            yc_fit = fit_result.ring_center_y.to_value(u.m) 
            r_fit = fit_result.ring_radius.to_value(u.m)  
            centroid= (xc_fit,yc_fit)
            dist= np.sqrt((geom.pix_x.value-xc_fit)**2 + (geom.pix_y.value-yc_fit)**2)
            ring_dist= np.abs(dist - r_fit)
            cut_outlier = ring_dist < r_fit * 0.4
            combined_mask = mask & cut_outlier
            chisquare = (np.sum(((ring_dist[combined_mask]/(angle_pix_width))**2))/(sum(combined_mask)))
            if method == "kundu_chaudhuri":
                #disp.add_ellipse(centroid = centroid, length=r_fit*2, width=r_fit*2, angle=0,color = 'yellow',lw = 2)
                allradius_ck.append(r_fit)
                allcenterx_ck.append(xc_fit)
                allcentery_ck.append(yc_fit)
                chisquares_ck.append(chisquare)
            elif method == "taubin":
                #disp.add_ellipse(centroid = centroid, length=r_fit*2, width=r_fit*2, angle=0,color = 'red',lw = 2)
                allradius_t.append(r_fit)
                allcenterx_t.append(xc_fit)
                allcentery_t.append(yc_fit)
                chisquares_t.append(chisquare)
            elif method == "hough":
                #disp.add_ellipse(centroid = centroid, length=r_fit*2, width=r_fit*2, angle=0,color = 'blue',lw = 2)
                allradius_h.append(r_fit)
                allcenterx_h.append(xc_fit)
                allcentery_h.append(yc_fit)
                chisquares_h.append(chisquare)
        pixelcharge = sum(image[mask])
        pixelcharge_all.append(pixelcharge)
        pixelnum = len(image[mask])
        pixelnumber_all.append(pixelnum)
        avg_dist = np.sqrt(sum((np.array(x)[mask])**2 + (np.array(y)[mask])**2))
        avgdist_all.append(avg_dist)
# Out:
# <hr>
# <table>
#     <tr>
#         <td title="Minimum value of function">FCN = 0.0029417176109258216</td>
#         <td title="Total number of call to FCN so far">TOTAL NCALL = 63</td>
#         <td title="Number of call in last migrad">NCALLS = 63</td>
#     </tr>
#     <tr>
#         <td title="Estimated distance to minimum">EDM = 1.4376669855943479e-05</td>
#         <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#         <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#         UP = 1.0</td>
#     </tr>
# </table>
# <table>
#     <tr>
#         <td align="center" title="Validity of the migrad call">Valid</td>
#         <td align="center" title="Validity of parameters">Valid Param</td>
#         <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#         <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
# ...

# %%
fit_values_opt60=[]
true_inclination_list_opt60=[]
true_radius_list_opt60=[]
true_centerx_list_opt60=[]
true_centery_list_opt60=[]
pixelcharge_all_opt60=[]
pixelnumber_all_opt60=[]
avgdist_all_opt60=[]


allcenterx_t_opt60=[]
allcentery_t_opt60=[]

allradius_t_opt60=[]
error_xvalues_t_opt60=[]
error_yvalues_t_opt60=[]
error_radius_t_opt60=[]
chisquares_t_opt60=[]
inclination_list_t_opt60=[]

allcenterx_ck_opt60=[]
allcentery_ck_opt60=[]
allradius_ck_opt60=[]
error_xvalues_ck_opt60=[]
error_yvalues_ck_opt60=[]
error_radius_ck_opt60=[]
chisquares_ck_opt60=[]
inclination_list_ck_opt60=[]

allcenterx_h_opt60 = []
allcentery_h_opt60 = []
allradius_h_opt60 = []
error_xvalues_h_opt60 = []
error_yvalues_h_opt60 = []
error_radius_h_opt60 = []
chisquares_h_opt60 = []
inclination_list_h_opt60 = []

# %%
source1 = event_source(filename2)
for event in source1:
    
    if event.count >100:
        break
    
    from ctapipe.calib import CameraCalibrator
    calib = CameraCalibrator()
    calib(event)

    tel_id = sorted(event.r1.tels_with_data)[0]
    sub = event.inst.subarray
    camera = sub.tel[tel_id].camera
    optics = sub.tel[tel_id].optics
    image = event.dl1.tel[tel_id].image

    for telid in event.dl0.tels_with_data:

        # Get geometry
        teldes = event.inst.subarray.tel[telid]
        focal_length= teldes.optics.equivalent_focal_length
        geom = teldes.camera

        mask = tailcuts_clean(geom, image, 10, 12)
        image[~mask] = 0
        x, y = np.array(geom.pix_x), np.array(geom.pix_y)
        
        squared_distanced = (x[0] - x[1:])**2 + (y[0] - y[1:])**2
        angle_pix_width = np.sqrt(squared_distanced.min())
        
        for method in MuonRingFitter.fit_method.values:

            muonfit = MuonRingFitter(fit_method=method)
            fit_result = muonfit(geom.pix_x, geom.pix_y, image, mask)
            
            #plt.figure(figsize=(5,5))
            disp = CameraDisplay(geom, image)
            
            xc_fit = fit_result.ring_center_x.to_value(u.m) 
            yc_fit = fit_result.ring_center_y.to_value(u.m) 
            r_fit = fit_result.ring_radius.to_value(u.m)  
            centroid= (xc_fit,yc_fit)
            dist= np.sqrt((geom.pix_x.value-xc_fit)**2 + (geom.pix_y.value-yc_fit)**2)
            ring_dist= np.abs(dist - r_fit)
            cut_outlier = ring_dist < r_fit * 0.4
            combined_mask = mask & cut_outlier
            chisquare = (np.sum(((ring_dist[combined_mask]/(angle_pix_width))**2))/(sum(combined_mask)))
            if method == "kundu_chaudhuri":
                #disp.add_ellipse(centroid = centroid, length=r_fit*2, width=r_fit*2, angle=0,color = 'yellow',lw = 2)
                allradius_ck_opt60.append(r_fit)
                allcenterx_ck_opt60.append(xc_fit)
                allcentery_ck_opt60.append(yc_fit)
                chisquares_ck_opt60.append(chisquare)
            elif method == "taubin":
                #disp.add_ellipse(centroid = centroid, length=r_fit*2, width=r_fit*2, angle=0,color = 'red',lw = 2)
                allradius_t_opt60.append(r_fit)
                allcenterx_t_opt60.append(xc_fit)
                allcentery_t_opt60.append(yc_fit)
                chisquares_t_opt60.append(chisquare)
            elif method == "hough":
                #disp.add_ellipse(centroid = centroid, length=r_fit*2, width=r_fit*2, angle=0,color = 'blue',lw = 2)
                allradius_h_opt60.append(r_fit)
                allcenterx_h_opt60.append(xc_fit)
                allcentery_h_opt60.append(yc_fit)
                chisquares_h_opt60.append(chisquare)
        pixelcharge = sum(image[mask])
        pixelcharge_all_opt60.append(pixelcharge)
        pixelnum = len(image[mask])
        pixelnumber_all_opt60.append(pixelnum)
        avg_dist = np.sqrt(sum((np.array(x)[mask])**2 + (np.array(y)[mask])**2))
        avgdist_all_opt60.append(avg_dist)
# Out:
# <hr>
# <table>
#     <tr>
#         <td title="Minimum value of function">FCN = 0.0019964344309732146</td>
#         <td title="Total number of call to FCN so far">TOTAL NCALL = 87</td>
#         <td title="Number of call in last migrad">NCALLS = 87</td>
#     </tr>
#     <tr>
#         <td title="Estimated distance to minimum">EDM = 5.79024328070028e-06</td>
#         <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#         <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#         UP = 1.0</td>
#     </tr>
# </table>
# <table>
#     <tr>
#         <td align="center" title="Validity of the migrad call">Valid</td>
#         <td align="center" title="Validity of parameters">Valid Param</td>
#         <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#         <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
# ...

# %%
plt.hist(chisquares_ck,label="opt100")
plt.hist(chisquares_ck_opt60,label="opt60")
plt.legend()
plt.xlabel("chisquares")
plt.ylabel("Counts")
plt.title("LSTCam:Chisquares with CK Opt100 vs Opt60")
# Out:
# /anaconda3/envs/cta-dev/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda3/envs/cta-dev/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# Text(0.5, 1.0, 'LSTCam:Chisquares with CK Opt100 vs Opt60')

# %%
plt.hist(chisquares_h,label="opt100")
plt.hist(chisquares_h_opt60,label="opt60")
plt.legend()
plt.xlabel("chisquares")
plt.ylabel("Counts")
plt.title("LSTCam:Chisquares with Hough Opt100 vs Opt60")
# Out:
# Text(0.5, 1.0, 'LSTCam:Chisquares with Hough Opt100 vs Opt60')

# %%
plt.hist(chisquares_t,label="opt100")
plt.hist(chisquares_t_opt60,label="opt60")
plt.legend()
plt.xlabel("chisquares")
plt.ylabel("Counts")
plt.title("LSTCam:Chisquares with Taubin Opt100 vs Opt60")
# Out:
# Text(0.5, 1.0, 'LSTCam:Chisquares with Taubin Opt100 vs Opt60')

# %%
plt.hist(pixelcharge_all,label='opt100')
plt.hist(pixelcharge_all_opt60,label='opt60')
plt.legend()
plt.xlabel("pixel charge")
plt.ylabel("counts")
plt.title("LSTCam Pixel Charge Comparison Opt100 vs Opt60")
# Out:
# Text(0.5, 1.0, 'LSTCam Pixel Charge Comparison Opt100 vs Opt60')

# %%
plt.hist(pixelnumber_all,label="opt100")
plt.hist(pixelnumber_all_opt60,label="opt60")
plt.legend()
plt.xlabel("Pixel number")
plt.ylabel("Counts")
plt.title("LSTCam Pix Number: Opt 100 vs 60")
# Out:
# Text(0.5, 1.0, 'LSTCam Pix Number: Opt 100 vs 60')

# %%
plt.hist(avgdist_all,label="opt100")
plt.hist(avgdist_all_opt60,label="opt60")
plt.legend()
plt.xlabel("Pixel number")
plt.ylabel("Counts")
plt.title("LSTCam Pix Number: Opt 100 vs 60")
# Out:
# Text(0.5, 1.0, 'LSTCam Pix Number: Opt 100 vs 60')

# %%
plt.plot(pixelcharge_all,chisquares_ck,"ro",label="ck-opt100")
plt.plot(pixelcharge_all_opt60,chisquares_ck_opt60,"bo",label="ck-opt60")
plt.plot(pixelcharge_all,chisquares_t,"go",label="t-opt100")
plt.plot(pixelcharge_all_opt60,chisquares_t_opt60,"yo",label="t-opt60")
plt.plot(pixelcharge_all,chisquares_h,"ko",label="h-opt100")
plt.plot(pixelcharge_all_opt60,chisquares_h_opt60,"mo",label="h-opt60")
plt.legend()
plt.xlabel("pixel charge")
plt.ylabel("chisquare")
plt.title("LSTCam Data Three Fits: PixelCharge vs Chisquare")
# Out:
# Text(0.5, 1.0, 'LSTCam Data Three Fits: PixelCharge vs Chisquare')

# %%
plt.plot(pixelnumber_all,chisquares_ck,"ro",label="ck-opt100")
plt.plot(pixelnumber_all_opt60,chisquares_ck_opt60,"bo",label="ck-opt60")
plt.plot(pixelnumber_all,chisquares_t,"go",label="t-opt100")
plt.plot(pixelnumber_all_opt60,chisquares_t_opt60,"yo",label="t-opt60")
plt.plot(pixelnumber_all,chisquares_h,"ko",label="h-opt100")
plt.plot(pixelnumber_all_opt60,chisquares_h_opt60,"mo",label="h-opt60")
plt.legend()
plt.xlabel("pixel number")
plt.ylabel("chisquare")
plt.title("LSTCam Data Opt 100 vs 60: PixelNum/Chisquare")
# Out:
# Text(0.5, 1.0, 'LSTCam Data Opt 100 vs 60: PixelNum/Chisquare')

# %%
plt.plot(avgdist_all,chisquares_ck,"ro",label="ck-opt100")
plt.plot(avgdist_all_opt60,chisquares_ck_opt60,"bo",label="ck-opt60")
plt.plot(avgdist_all,chisquares_t,"go",label="t-opt100")
plt.plot(avgdist_all_opt60,chisquares_t_opt60,"yo",label="t-opt60")
plt.plot(avgdist_all,chisquares_h,"ko",label="h-opt100")
plt.plot(avgdist_all_opt60,chisquares_h_opt60,"mo",label="h-opt60")
plt.legend()
plt.xlabel("avgdist")
plt.ylabel("chisquare")
plt.title("LSTCam Data Three Fits: Avgdist vs Chisquare")
# Out:
# Text(0.5, 1.0, 'LSTCam Data Three Fits: Avgdist vs Chisquare')

# %%
#defining bad chi-sq >= 2
mask_badchisq_t = np.array(chisquares_t)>2.
mask_badchisq_ck= np.array(chisquares_ck)>2.
mask_badchisq_h = np.array(chisquares_h)>2
mask_badchisq_t_opt60 = np.array(chisquares_t_opt60)>2.
mask_badchisq_ck_opt60= np.array(chisquares_ck_opt60)>2.
mask_badchisq_h_opt60 = np.array(chisquares_h_opt60)>2
# Out:
# /anaconda3/envs/cta-dev/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater
#   """
# /anaconda3/envs/cta-dev/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in greater
#
# /anaconda3/envs/cta-dev/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in greater
#   import sys

# %%
#bad chi-square percentage
print(len(np.array(chisquares_t)[mask_badchisq_t])/len(np.array(chisquares_t)))
print(len(np.array(chisquares_ck)[mask_badchisq_ck])/len(np.array(chisquares_ck)))
print(len(np.array(chisquares_h)[mask_badchisq_h])/len(np.array(chisquares_h)))
print(len(np.array(chisquares_t_opt60)[mask_badchisq_t_opt60])/len(np.array(chisquares_t_opt60)))
print(len(np.array(chisquares_ck_opt60)[mask_badchisq_ck_opt60])/len(np.array(chisquares_ck_opt60)))
print(len(np.array(chisquares_h_opt60)[mask_badchisq_h_opt60])/len(np.array(chisquares_h_opt60)))
# Out:
# 0.18811881188118812
# 0.0297029702970297
# 0.09900990099009901
# 0.16831683168316833
# 0.009900990099009901
# 0.0891089108910891
